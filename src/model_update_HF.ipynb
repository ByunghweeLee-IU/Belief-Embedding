# %%
import torch
from sentence_transformers import SentenceTransformer
from huggingface_hub import notebook_login
from huggingface_hub import HfApi

# %%
notebook_login()

# %%
model = SentenceTransformer("../model/full_data/roberta-base_idx0_epoch3/")

# %%
model.push_to_hub("Byunghwee/roberta_belief_finetuned")
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# 'https://huggingface.co/Byunghwee/roberta_belief_finetuned/commit/0e5c475bba6abccfaf585f4ef26b633c62591e07'

# %%
api = HfApi()
api.upload_file(
    path_or_fileobj="../model/full_data/roberta-base_idx0_epoch3/README.md",
    path_in_repo="README.md",
    repo_id="Byunghwee/roberta_belief_finetuned",
    repo_type="model"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Byunghwee/roberta_belief_finetuned/commit/194c97ff7ddfaa74e5a5823b9b79e43118e1662f', commit_message='Upload README.md with huggingface_hub', commit_description='', oid='194c97ff7ddfaa74e5a5823b9b79e43118e1662f', pr_url=None, pr_revision=None, pr_num=None)
