# %%
import pickle
import pandas as pd
from pandas import Series
from tqdm import tqdm
import seaborn as sns
import numpy as np

import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
from matplotlib import rc


matplotlib.rcParams['figure.dpi'] = 150
f_path = "/System/Library/Fonts/Helvetica.ttc"
font_name = fm.FontProperties(fname=f_path).get_name()
rc('font', family=font_name, size=13)

# %% [markdown]
# ## Read classification results

# %%
df = pd.read_pickle('../dataset/03_Final_dataframe/df_ddo_with_isbelief_info(N232691).p')
len(df)
# Out:
# 232691

# %%
df = df[~df.duplicated()]
df.to_pickle('../dataset/03_Final_dataframe/df_ddo_with_isbelief_info_nodup(N226847).p')

# %%
print('data size:', len(df))
print('num debates:', len(df['debate_key'].unique()))
print('num debate title:', len(df['debate_title'].unique()))
print('num users:', len(df['username'].unique()))
print('average participation:', len(df)/len(df['username'].unique())  )
# Out:
# data size: 226847
# num debates: 78362
# num debate title: 68900
# num users: 44510
# average participation: 5.096540103347563

# %%
df.head()
# Out:
#                                           debate_key  \
# 0                .-.-.-Ha-YOURE-GOING-DOWN-BEEM0R/1/
# 1  .-Audis-are-junkers-except-to-rich-kids-with-l...
# 2  ....-Former-Secretary-of-State-Madeleine-Albri...
# 3                     ...Words-can-t-hurt-me-any./1/
# 4                      .9-repeated-is-equal-to-1./1/
#
#                                         debate_title         username  \
# 0               . . . Ha! YOU'RE GOING DOWN, BEEM0R!   Logical-Master
# 1  . Audis are junkers, except to rich kids with ...      Max.Wallace
# 2  ...."Former Secretary of State Madeleine Albri...  Lookingatissues
# 3                        ...Words can't hurt me any.     NonInDelicto
# 4                         .9 repeated is equal to 1.       cowpie1998
#
#   debate_date position  is_belief
# 0  2009-02-02      Pro        0.0
# 1  2014-09-04      Pro        1.0
# 2  2017-01-30      Pro        1.0
# 3  2007-12-19      Pro        1.0
# 4  2011-04-07      Pro        1.0

# %%
df_true = df[df['is_belief']==1]
df_false = df[df['is_belief']==0]

true_beliefs = pd.Series(df_true['debate_title'].unique())
false_beliefs = pd.Series(df_false['debate_title'].unique())

# %%
len(df_true), len(df_false)
# Out:
# (192307, 34497)

# %%
df_sampled = pd.concat([true_beliefs.sample(25), false_beliefs.sample(25)], ignore_index=1)

# %%
df_sampled = pd.DataFrame(df_sampled, columns=['debate_title'])
gpt_labels = np.concatenate((np.ones(25), np.zeros(25)))
df_sampled['GPT-4_Answer'] = gpt_labels.astype(int)
df_sampled
# Out:
#                                          debate_title  GPT-4_Answer
# 0           The Qur'an is not the truth, Jesus is God             1
# 1             tom brady is better than peyton manning             1
# 2   Any government attempts to bail out homeowners...             1
# 3                         Metal Detectors in Schools?             1
# 4   Government should get out of the marriage busi...             1
# 5              Should Jerusalem be a Jewish territory             1
# 6       The United States needs Universal Healthcare.             1
# 7   Should we, as christians, Doubt the Bible some...             1
# 8   Since good secure more happiness, we should li...             1
# 9                           Beauty is only skin deep.             1
# 10  7-Day Cycle of Masturbation Abstinence Helps A...             1
# 11  Should studens be forced to take an exra curri...             1
# 12  The death penalty, is it A- Morally Right and ...             1
# 13  In the United States, Minor Jail Time Ought to...             1
# 14  Nuclear weapons are a necessary evil, and disa...             1
# 15  Anarcho-capitalism is the right form of govern...             1
# 16  Chemical sterilization for non-custodial paren...             1
# 17        Do or Do Not there is no try. Do you Agree?             1
# 18                         Terrorism Can Be Justified             1
# 19                        Is rap/hip-hop music "bad"?             1
# 20                  Should gay marriage be allowed???             1
# 21  Resolved: The term "terrorist" is discriminato...             1
# 22                     Religion is a modern day myth.             1
# 23                         Should pooping be Illegal?             1
# 24  The Patriots undefeated season should have an ...             1
# 25                                 Design Your Prison             0
# 26                                    CBA Child Abuse             0
# 27                                  Surrogate Mothers             0
# 28  Best way to murder somebody without getting ca...             0
# 29                      Were classical composers gay?             0
# 30                                 Stand your ground.             0
# 31                         Agriculture vs. Population             0
# 32                                           Eugenics             0
# 33                                  Stateless society             0
# 34                                 Riddle of Epicuris             0
# 35                                 Interactive novels             0
# 36                 Dr. Ben Carson or Hillary Clinton?             0
# 37                                        Mars colony             0
# 38                                     Nuclear power.             0
# 39                      should gay marriage be legal?             0
# 40                               Random Poetry Battle             0
# 41                                    Give me riddles             0
# 42                                Just for fun! 1+1=2             0
# 43  High school, 8th grade and off into a big scho...             0
# 44                                             fasion             0
# 45  Prove that the god according to the bible love...             0
# 46                              New Lyrical Challenge             0
# 47                       Irish vs. British rap battle             0
# 48                     Batman (pro) VS Deadpool (con)             0
# 49                                         LD Debates             0

# %%
# Shuffle the DataFrame
shuffled_df = df_sampled.sample(frac=1, random_state=42)  # `random_state` is optional

# Reset the index if you want to also reorder the index
shuffled_df = shuffled_df.reset_index(drop=True)

# %%
shuffled_df
# Out:
#                                          debate_title  GPT-4_Answer
# 0   In the United States, Minor Jail Time Ought to...             1
# 1                       should gay marriage be legal?             0
# 2                                  Stand your ground.             0
# 3   Prove that the god according to the bible love...             0
# 4         Do or Do Not there is no try. Do you Agree?             1
# 5                      Batman (pro) VS Deadpool (con)             0
# 6                                     CBA Child Abuse             0
# 7                                  Design Your Prison             0
# 8                                            Eugenics             0
# 9                         Is rap/hip-hop music "bad"?             1
# 10  The death penalty, is it A- Morally Right and ...             1
# 11  Government should get out of the marriage busi...             1
# 12                                        Mars colony             0
# 13  Since good secure more happiness, we should li...             1
# 14                        Metal Detectors in Schools?             1
# 15      The United States needs Universal Healthcare.             1
# 16                                    Give me riddles             0
# 17                              New Lyrical Challenge             0
# 18                       Irish vs. British rap battle             0
# 19  Anarcho-capitalism is the right form of govern...             1
# 20                          Beauty is only skin deep.             1
# 21  Chemical sterilization for non-custodial paren...             1
# 22  The Patriots undefeated season should have an ...             1
# 23                                 Riddle of Epicuris             0
# 24                         Agriculture vs. Population             0
# 25          The Qur'an is not the truth, Jesus is God             1
# 26                                             fasion             0
# 27                                  Surrogate Mothers             0
# 28                                  Stateless society             0
# 29             Should Jerusalem be a Jewish territory             1
# 30                      Were classical composers gay?             0
# 31  Should studens be forced to take an exra curri...             1
# 32                 Dr. Ben Carson or Hillary Clinton?             0
# 33            tom brady is better than peyton manning             1
# 34  Resolved: The term "terrorist" is discriminato...             1
# 35  Any government attempts to bail out homeowners...             1
# 36  High school, 8th grade and off into a big scho...             0
# 37                                 Interactive novels             0
# 38                         Should pooping be Illegal?             1
# 39                               Random Poetry Battle             0
# 40  7-Day Cycle of Masturbation Abstinence Helps A...             1
# 41                     Religion is a modern day myth.             1
# 42                         Terrorism Can Be Justified             1
# 43                                         LD Debates             0
# 44                  Should gay marriage be allowed???             1
# 45  Should we, as christians, Doubt the Bible some...             1
# 46                                Just for fun! 1+1=2             0
# 47  Nuclear weapons are a necessary evil, and disa...             1
# 48  Best way to murder somebody without getting ca...             0
# 49                                     Nuclear power.             0

# %%
shuffled_df.to_csv('../dataset/03_belief_filtering_GPT4_result_essential_data/gpt-4_belief_classification.csv', index=False)
